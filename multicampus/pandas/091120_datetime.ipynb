# %% [markdown]
# # 파이썬에서 날짜와 시간 다루기

# %% [markdown]
# ## datetime 패키지

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2020, 9, 11, 10, 49, 16, 169160)

# %%
print(datetime.today())
# Out:
# 2020-09-11 10:44:04.797180

# %%
t1 = datetime.now()
print(t1)
t2 = datetime(2020, 9, 11)
print(t2)
# Out:
# 2020-09-11 10:44:04.973434
# 2020-09-11 00:00:00

# %% [markdown]
# ### 시간 연산

# %%
t1 - t2
# Out:
# datetime.timedelta(seconds=38644, microseconds=973434)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
ebola = pd.read_csv("country_timeseries.csv")
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola['Date_dt'] = pd.to_datetime(ebola['Date'])
ebola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df2 = pd.DataFrame({'order_day': ['01-01-20', '01-02-20']})
df2['date_dt'] = pd.to_datetime(df2['order_day'])
df2['date_dt2'] = pd.to_datetime(df2['order_day'], format="%m-%d-%y")
df2
# Out:
#   order_day    date_dt   date_dt2
# 0  01-01-20 2020-01-01 2020-01-01
# 1  01-02-20 2020-01-02 2020-01-02

# %% [markdown]
# ### strftime

# %%
now = datetime.now()
now.strftime("%m-%d-%y %H:%M:%S")
# Out:
# '09-11-20 10:44:06'

# %% [markdown]
# ### datetime 형식으로 데이터프레임 생성

# %%
ebola2 = pd.read_csv("country_timeseries.csv", parse_dates=['Date'])
ebola2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
print(ebola2['Date'][0].year)
print(ebola2['Date'][0].month)
print(ebola2['Date'][0].day)
# Out:
# 2015
# 1
# 5

# %%
ebola3 = pd.read_csv("country_timeseries.csv")
ebola3.info()
ebola['Date_dt'] = pd.to_datetime(ebola3['Date'])
ebola3
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %% [markdown]
# ### datetime 클래스 메서드

# %%
ebola['Date_dt'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4      12
#        ..
# 117     3
# 118     3
# 119     3
# 120     3
# 121     3
# Name: Date_dt, Length: 122, dtype: int64

# %%
print(ebola['Date_dt'].max())
print(ebola['Date_dt'].min())
print(ebola['Date_dt'].mean())
# Out:
# 2015-01-05 00:00:00
# 2014-03-22 00:00:00
# 2014-08-13 20:15:44.262295040

# %% [markdown]
# #### 퀴즈

# %% [markdown]
# * 에볼라 최초 발병일

# %%
ebola['Date_dt'].min().strftime("%Y-%m-%d")
# Out:
# '2014-03-22'

# %% [markdown]
# * 에볼라 발병 경과일(최종 - 최초)

# %%
print(ebola['Date_dt'].max() - ebola['Date_dt'].min())
# Out:
# 289 days 00:00:00

# %%
banks = pd.read_csv("../pandas_data/banklist.csv", parse_dates=['Closing Date', 'Updated Date'])

# %%
banks.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date
# 0                   Royal Savings Bank   2017-12-15   2017-12-20
# 1                          Conway Bank   2017-10-13   2017-10-20
# 2            United Fidelity Bank, fsb   2017-05-26   2017-07-26
# 3  First-Citizens Bank & Trust Company   2017-05-05   2017-07-26
# 4                         Whitney Bank   2017-04-28   2017-12-05

# %%
# print(banks['Closing Date'].dt.year)
# print(banks['Closing Date'].dt.month)
# print(banks['Closing Date'].dt.day)
banks['Closing Date'].dt.quarter.value_counts()
# Out:
# 3    153
# 2    138
# 1    135
# 4    129
# Name: Closing Date, dtype: int64

# %%
banks['Closing Year'] = banks['Closing Date'].dt.year
banks['Closing Quarter'] = banks['Closing Date'].dt.quarter

# %%
cyq = banks.groupby(['Closing Year', 'Closing Quarter']).size()
cy = banks.groupby(['Closing Year']).size()

# %%
cyq.plot()

# %%
import pandas_datareader as pdr

# %%
# tesla = pdr.get_data_qunadl('TSLA')
# tesla.to_csv("tsla.csv")

# %%
tesla = pd.read_csv("../pandas_data/tesla_stock_quandl.csv", parse_dates=['Date']) # parse_dates=[0]
tesla.head()
# Out:
#         Date    Open    High     Low   Close      Volume  ExDividend  \
# 0 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 1 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 3 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 4 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 0         1.0   304.00   304.27  277.18    279.18  13696168.0
# 1         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2         1.0   311.25   311.61  300.45    301.54   6600538.0
# 3         1.0   313.89   318.82  308.18    309.10   4914307.0
# 4         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
tesla.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1949 entries, 0 to 1948
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1949 non-null   datetime64[ns]
#  1   Open        1949 non-null   float64
#  2   High        1949 non-null   float64
#  3   Low         1949 non-null   float64
#  4   Close       1949 non-null   float64
#  5   Volume      1949 non-null   float64
#  6   ExDividend  1949 non-null   float64
#  7   SplitRatio  1949 non-null   float64
#  8   AdjOpen     1949 non-null   float64
#  9   AdjHigh     1949 non-null   float64
#  10  AdjLow      1949 non-null   float64
#  11  AdjClose    1949 non-null   float64
#  12  AdjVolume   1949 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 198.1 KB

# %% [markdown]
# ### datetime 인덱스

# %% [markdown]
# datetime을 인덱스로 사용 시, 년 월 일 등으로 행을 조회할 수 있다

# %%
tesla[tesla['Date'].dt.year > 2010]
# Out:
#            Date    Open      High     Low   Close      Volume  ExDividend  \
# 0    2018-03-27  304.00  304.2700  277.18  279.18  13696168.0         0.0
# 1    2018-03-26  307.34  307.5900  291.36  304.18   8324639.0         0.0
# 2    2018-03-23  311.25  311.6100  300.45  301.54   6600538.0         0.0
# 3    2018-03-22  313.89  318.8200  308.18  309.10   4914307.0         0.0
# 4    2018-03-21  310.25  322.4400  310.19  316.53   5927881.0         0.0
# ...         ...     ...       ...     ...     ...         ...         ...
# 1814 2011-01-07   28.00   28.5800   27.90   28.24   2247900.0         0.0
# 1815 2011-01-06   26.83   28.0000   26.81   27.88   2061200.0         0.0
# 1816 2011-01-05   26.48   26.9000   26.19   26.83   1446700.0         0.0
# 1817 2011-01-04   26.66   26.9500   26.02   26.67   1187400.0         0.0
# 1818 2011-01-03   26.84   26.9999   25.90   26.62   1283000.0         0.0
#
#       SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose   AdjVolume
# ...

# %%
tesla[(tesla['Date'].dt.year == 2010) & (tesla['Date'].dt.month == 6)]
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %%
tesla.index = tesla['Date']

# %%
tesla.head()
# Out:
#                  Date    Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# 2018-03-27         1.0   304.00   304.27  277.18    279.18  13696168.0
# 2018-03-26         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2018-03-23         1.0   311.25   311.61  300.45    301.54   6600538.0
# 2018-03-22         1.0   313.89   318.82  308.18    309.10   4914307.0
# 2018-03-21         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
tesla['2015']
# Out:
#                  Date    Open      High       Low    Close     Volume  \
# Date
# 2015-12-31 2015-12-31  238.51  243.4500  238.3700  240.010  2715038.0
# 2015-12-30 2015-12-30  236.60  243.6340  235.6707  238.090  3697921.0
# 2015-12-29 2015-12-29  230.06  237.7200  229.5470  237.190  2406290.0
# 2015-12-28 2015-12-28  231.49  231.9800  225.5400  228.950  1901304.0
# 2015-12-24 2015-12-24  230.56  231.8800  228.2800  230.570   710277.0
# ...               ...     ...       ...       ...      ...        ...
# 2015-01-08 2015-01-08  212.81  213.7999  210.0100  210.615  3442509.0
# 2015-01-07 2015-01-07  213.35  214.7800  209.7800  210.950  2968390.0
# 2015-01-06 2015-01-06  210.06  214.2000  204.2100  211.280  6261936.0
# 2015-01-05 2015-01-05  214.55  216.5000  207.1626  210.090  5368477.0
# 2015-01-02 2015-01-02  222.87  223.2500  213.2600  219.310  4764443.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh    AdjLow  AdjClose  \
# Date
# ...

# %%
tesla['refDate'] = tesla['Date'] - tesla['Date'].min()
tesla.head()
# Out:
#                  Date    Open    High     Low   Close      Volume  ExDividend  \
# Date
# 2018-03-27 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 2018-03-26 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2018-03-23 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 2018-03-22 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 2018-03-21 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#             SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume  \
# Date
# 2018-03-27         1.0   304.00   304.27  277.18    279.18  13696168.0
# 2018-03-26         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2018-03-23         1.0   311.25   311.61  300.45    301.54   6600538.0
# 2018-03-22         1.0   313.89   318.82  308.18    309.10   4914307.0
# 2018-03-21         1.0   310.25   322.44  310.19    316.53   5927881.0
#
#              refDate
# Date
# 2018-03-27 2828 days
# ...

# %%
tesla['Volume'].idxmax()
tesla.iloc[tesla['Volume'].argmax()]['Date']
tesla[tesla['Volume'] == tesla['Volume'].max()]['Date'][0]
